# %% [markdown]
# <a href="https://colab.research.google.com/github/karthikshanthp/colab/blob/main/titanic_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pip install pyspark
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488491 sha256=6e213a63ee2c3b90f6563d138f742e001938e3ddb2f270097a5859279b90ec4e
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# ...

# %%
import pyspark

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

# %%
# create spark session object
spark =  SparkSession.builder.appName("titanic analysis").getOrCreate()

# %%
#Define dataframe df. Read the file and load it in spark object
df = spark.read.load("/content/Titanic.parquet", format="parquet")
# df2= spark.read.parquet("/content/Titanic.parquet")

# %%
#Inspect the newly created df object by using head() or show() functions
# df.head()
df.show(10)
# Out:
# +-----------+--------+------+--------------------+------+----+-----+-----+----------------+-------+-----+--------+
# |PassengerId|Survived|Pclass|                Name|   Sex| Age|SibSp|Parch|          Ticket|   Fare|Cabin|Embarked|
# +-----------+--------+------+--------------------+------+----+-----+-----+----------------+-------+-----+--------+
# |          1|       0|     3|Braund, Mr. Owen ...|  male|22.0|    1|    0|       A/5 21171|   7.25| NULL|       S|
# |          2|       1|     1|Cumings, Mrs. Joh...|female|38.0|    1|    0|        PC 17599|71.2833|  C85|       C|
# |          3|       1|     3|Heikkinen, Miss. ...|female|26.0|    0|    0|STON/O2. 3101282|  7.925| NULL|       S|
# |          4|       1|     1|Futrelle, Mrs. Ja...|female|35.0|    1|    0|          113803|   53.1| C123|       S|
# |          5|       0|     3|Allen, Mr. Willia...|  male|35.0|    0|    0|          373450|   8.05| NULL|       S|
# ...

# %%
# df.count()
# df.show(891)
df.dtypes
# Out:
# [('PassengerId', 'bigint'),
#  ('Survived', 'bigint'),
#  ('Pclass', 'bigint'),
#  ('Name', 'string'),
#  ('Sex', 'string'),
#  ('Age', 'double'),
#  ('SibSp', 'bigint'),
#  ('Parch', 'bigint'),
#  ('Ticket', 'string'),
#  ('Fare', 'double'),
#  ('Cabin', 'string'),
#  ('Embarked', 'string')]

# %%
df.show(df.count())
# Out:
# +-----------+--------+------+--------------------+------+----+-----+-----+------------------+--------+---------------+--------+
# |PassengerId|Survived|Pclass|                Name|   Sex| Age|SibSp|Parch|            Ticket|    Fare|          Cabin|Embarked|
# +-----------+--------+------+--------------------+------+----+-----+-----+------------------+--------+---------------+--------+
# |          1|       0|     3|Braund, Mr. Owen ...|  male|22.0|    1|    0|         A/5 21171|    7.25|           NULL|       S|
# |          2|       1|     1|Cumings, Mrs. Joh...|female|38.0|    1|    0|          PC 17599| 71.2833|            C85|       C|
# |          3|       1|     3|Heikkinen, Miss. ...|female|26.0|    0|    0|  STON/O2. 3101282|   7.925|           NULL|       S|
# |          4|       1|     1|Futrelle, Mrs. Ja...|female|35.0|    1|    0|            113803|    53.1|           C123|       S|
# ...

# %%
pip install snowflake-connector-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 23.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 kB 10.5 MB/s eta 0:00:00
# ...
