# %%
pip install pyspark==3.1.3
# Out:
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/214.0 MB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/214.0 MB 621.0 kB/s eta 0:05:45
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.1/214.0 MB 1.1 MB/s eta 0:03:09
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.3/214.0 MB 3.0 MB/s eta 0:01:11
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.7/214.0 MB 4.8 MB/s eta 0:00:45
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/214.0 MB 6.2 MB/s eta 0:00:35
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/214.0 MB 7.9 MB/s eta 0:00:27
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/214.0 MB 9.8 MB/s eta 0:00:22
#      ╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/214.0 MB 11.9 MB/s eta 0:00:18
#      ╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/214.0 MB 13.7 MB/s eta 0:00:16
# ...

# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col

spark = SparkSession.builder.appName('Dataframe').getOrCreate()

# %%
df= spark.read.json("/content/sample_data/anscombe.json")
df2=spark.read.load("/content/sample_data/anscombe.json", format="json")
df.show()

# %%
# dbfs:/FileStore/Film.JSON
df=spark.read.load("/FileStore/Customer.csv", format="csv", header=True)

# %%
dfRen = df.withColumn("PaymentMethod", df["Payment Method"])
dfCustomer = dfRen.drop("Payment Method")

# %%
dfCustomer.show()
# Out:
# +---+------+-----+-------------+
# |Age|Gender|Label|PaymentMethod|
# +---+------+-----+-------------+
# | 64|  male|  yes|  credit card|
# | 35|  male|  yes|       cheque|
# | 25|female|  yes|  credit card|
# | 39|female|   no|  credit card|
# | 39|  male|  yes|  credit card|
# | 28|female|   no|       cheque|
# | 21|female|  yes|  credit card|
# | 48|  male|  yes|  credit card|
# | 70|female|   no|  credit card|
# | 36|  male|  yes|  credit card|
# | 22|  male|  yes|  credit card|
# | 53|female|   no|         cash|
# | 27|  male|  yes|         cash|
# | 40|  male|  yes|  credit card|
# | 22|  male|  yes|         cash|
# | 49|female|   no|  credit card|
# | 24|female|   no|         cash|
# | 45|  male|  yes|  credit card|
# | 45|  male|  yes|  credit card|
# | 66|female|   no|         cash|
# +---+------+-----+-------------+
# only showing top 20 rows

# %%
dfCustomer.write.mode("overwrite").saveAsTable('customer')

# %%
# %sql
select * from customer
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select  * from customer where gender='male' limit 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
